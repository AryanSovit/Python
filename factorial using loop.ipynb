# %%
#write a program for the factorial using for loop
#hint: 
#fact = fact*i
#for <variable> in <sequence>:

n=int(input())
fact = 1
for i in range(1,n+1):
    fact*=i

print(fact)
# Out:
#  5
# 120
